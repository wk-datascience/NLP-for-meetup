# %%
import pandas as pd

# %%
df = pd.read_pickle('test_dataset.pickle')

# %%
df
# Out:
#                               created  \
# 0      Sat Nov 05 15:55:05 +0000 2016
# 1      Sat Nov 05 15:55:05 +0000 2016
# 2      Sat Nov 05 15:55:06 +0000 2016
# 3      Sat Nov 05 15:55:05 +0000 2016
# 4      Sat Nov 05 15:55:07 +0000 2016
# 5      Sat Nov 05 15:55:07 +0000 2016
# 6      Sat Nov 05 15:55:07 +0000 2016
# 7      Sat Nov 05 15:55:06 +0000 2016
# 8      Sat Nov 05 15:55:07 +0000 2016
# 9      Sat Nov 05 15:55:07 +0000 2016
# 10     Sat Nov 05 15:55:08 +0000 2016
# 11     Sat Nov 05 15:55:08 +0000 2016
# 12     Sat Nov 05 15:55:09 +0000 2016
# 13     Sat Nov 05 15:55:09 +0000 2016
# 14     Sat Nov 05 15:55:10 +0000 2016
# 15     Sat Nov 05 15:55:10 +0000 2016
# 16     Sat Nov 05 15:55:11 +0000 2016
# 17     Sat Nov 05 15:55:11 +0000 2016
# 18     Sat Nov 05 15:55:11 +0000 2016
# 19     Sat Nov 05 15:55:11 +0000 2016
# 20     Sat Nov 05 15:55:11 +0000 2016
# 21     Sat Nov 05 15:55:12 +0000 2016
# 22     Sat Nov 05 15:55:12 +0000 2016
# ...

# %%
df.text[0]
# Out:
# 'I\'m excited "Run The Wicked Away" it  is #7 in the Denmark iTunes Reggae Charts top 200 tracks! \nAvailable now 99p… https://t.co/HwPEySV432'

# %%
sentence = df.text[0]

# %%
#najprostszy tokenizer

# %%
sentence.split()
# Out:
# ["I'm",
#  'excited',
#  '"Run',
#  'The',
#  'Wicked',
#  'Away"',
#  'it',
#  'is',
#  '#7',
#  'in',
#  'the',
#  'Denmark',
#  'iTunes',
#  'Reggae',
#  'Charts',
#  'top',
#  '200',
#  'tracks!',
#  'Available',
#  'now',
#  '99p…',
#  'https://t.co/HwPEySV432']

# %%
from nltk.tokenize import word_tokenize, regexp_tokenize, wordpunct_tokenize

# %%
word_tokenize(sentence)
# Out:
# ['I',
#  "'m",
#  'excited',
#  '``',
#  'Run',
#  'The',
#  'Wicked',
#  'Away',
#  "''",
#  'it',
#  'is',
#  '#',
#  '7',
#  'in',
#  'the',
#  'Denmark',
#  'iTunes',
#  'Reggae',
#  'Charts',
#  'top',
#  '200',
#  'tracks',
#  '!',
#  'Available',
#  'now',
#  '99p…',
#  'https',
#  ':',
#  '//t.co/HwPEySV432']

# %%
regexp_tokenize(sentence, pattern='\w+|\$[\d\.]+|\S+')
# Out:
# ['I',
#  "'m",
#  'excited',
#  '"Run',
#  'The',
#  'Wicked',
#  'Away',
#  '"',
#  'it',
#  'is',
#  '#7',
#  'in',
#  'the',
#  'Denmark',
#  'iTunes',
#  'Reggae',
#  'Charts',
#  'top',
#  '200',
#  'tracks',
#  '!',
#  'Available',
#  'now',
#  '99p',
#  '…',
#  'https',
#  '://t.co/HwPEySV432']

# %%
wordpunct_tokenize(sentence)
# Out:
# ['I',
#  "'",
#  'm',
#  'excited',
#  '"',
#  'Run',
#  'The',
#  'Wicked',
#  'Away',
#  '"',
#  'it',
#  'is',
#  '#',
#  '7',
#  'in',
#  'the',
#  'Denmark',
#  'iTunes',
#  'Reggae',
#  'Charts',
#  'top',
#  '200',
#  'tracks',
#  '!',
#  'Available',
#  'now',
#  '99p',
#  '…',
#  'https',
#  '://',
#  't',
#  '.',
#  'co',
#  '/',
#  'HwPEySV432']

# %%
# tokenizery specjalne

# %%
from nltk.tokenize import TweetTokenizer

# %%
TweetTokenizer().tokenize(sentence)
# Out:
# ["I'm",
#  'excited',
#  '"',
#  'Run',
#  'The',
#  'Wicked',
#  'Away',
#  '"',
#  'it',
#  'is',
#  '#',
#  '7',
#  'in',
#  'the',
#  'Denmark',
#  'iTunes',
#  'Reggae',
#  'Charts',
#  'top',
#  '200',
#  'tracks',
#  '!',
#  'Available',
#  'now',
#  '99p',
#  '…',
#  'https://t.co/HwPEySV432']
